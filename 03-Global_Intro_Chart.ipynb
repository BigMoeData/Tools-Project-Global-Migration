# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings

# %load_ext watermark

# %watermark -v -p os,pandas,matplotlib
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# Python implementation: CPython
# Python version       : 3.10.8
# IPython version      : 8.8.0
#
# os        : unknown
# pandas    : 1.5.2
# matplotlib: 3.6.2

# %% [markdown]
# Python implementation: CPython
# Python version       : 3.10.8
# IPython version      : 8.8.0
#
# os               : unknown
# sys              : 3.10.8 (main, Nov 24 2022, 08:08:27) [Clang 14.0.6 ]
# pandas           : 1.5.2
# pandas_datareader: 0.10.0

# %%
warnings.filterwarnings("ignore")
#warnings.filterwarnings("defalt")

# %%
# Global Variables

data_file_path = 'Data'
image_file_path = 'Images'

# %%
the_df = pd.read_csv ( os.path.join ( data_file_path, "Master_Global_Data_2000_2019.csv" ) )

print (the_df.columns.tolist())
the_df.head(10)
# Out:
# ['year', 'population', 'migration_outflows', 'migration_inflows', 'migration_flow_percent', 'migration_net', 'migration_net_percent']
#    year    population  migration_outflows  migration_inflows  \
# 0  2000  6.122149e+09          -6080517.0          6094612.0
# 1  2001  6.204009e+09          -5230907.0          5226329.0
# 2  2002  6.285683e+09          -6407331.0          6400746.0
# 3  2003  6.366908e+09          -5928647.0          5925313.0
# 4  2004  6.448284e+09          -5694224.0          5698402.0
# 5  2005  6.529978e+09          -6497101.0          6504742.0
# 6  2006  6.612296e+09          -8222083.0          8219823.0
# 7  2007  6.694976e+09          -8515480.0          8514608.0
# 8  2008  6.778716e+09          -7877773.0          7884360.0
# 9  2009  6.862780e+09          -6594817.0          6602539.0
#
#    migration_flow_percent  migration_net  migration_net_percent
# 0                0.099550        14095.0           2.302296e-06
# ...

# %%
sns.set_style("whitegrid")

# Create a figure and a set of subplots
fig, ax1 = plt.subplots(figsize=(10, 6))

# Bar chart for migration data
sns.barplot(data = the_df, x = 'year', y = 'migration_flow_percent', color='blue', ax = ax1)
ax1.set_ylabel('Migration as a Percent of Global Population', color = 'blue')
ax1.tick_params(axis = 'y', labelcolor = 'blue')

# Create a twin Axes sharing the xaxis
#ax2 = ax1.twinx()

# Line chart for population data
#sns.lineplot(data = the_df, x = 'year', y = 'population', color = 'red', ax = ax2)
#ax2.set_ylabel('Population', color='red')
#ax2.tick_params(axis = 'y', labelcolor='red')

# Set titles and labels
plt.title('Migration as a Percent of Global Population (2000-2019)')
plt.xlabel('Year')

plt.savefig( os.path.join ( image_file_path, "Global_Migration_Data_2000_2019.jpg" ) )  # For JPG format
plt.savefig( os.path.join ( image_file_path, "Global_Migration_Data_2000_2019.png" ))  # For PNG format

# Show the plot
#plt.show()
